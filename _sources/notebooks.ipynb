# %% [markdown]
# Membaca data dari url link :https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/blood_pressure.csv

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/Opensourcefordatascience/Data-sets/master/blood_pressure.csv'
c = pd.read_csv(url)
print(c)
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   patient    120 non-null    int64
#  1   sex        120 non-null    object
#  2   agegrp     120 non-null    object
#  3   bp_before  120 non-null    int64
#  4   bp_after   120 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 4.8+ KB

# %%
#tabel data
c
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %% [markdown]
# 2. Membuat statistik deskriptif(misalkan rata"/numerik) dari data (setiap atribut yang bertipe numerik)

# %%
#data statistik pada kolom sebelum bp
c['bp_before'].describe()
# Out:
# count    120.000000
# mean     156.450000
# std       11.389845
# min      138.000000
# 25%      147.000000
# 50%      154.500000
# 75%      164.000000
# max      185.000000
# Name: bp_before, dtype: float64

# %% [markdown]
# 3.Mendeskripsikan kemiringan/skewned dari setiap variabel beritpe numerik

# %%
import seaborn as sns

# %%
sns.displot(c['bp_before']);
